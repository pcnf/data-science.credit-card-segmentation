# %% [markdown]
# ## Recency, Frequency, Monetary
#
# RFM model combines three different customer attributes to rank customers:
# * **Recency (R)**: Who have purchased recently? Number of days since last purchase
# * **Frequency (F)**: Who has purchased frequently? The total number of purchases
# * **Monetary Value(M)**: Who has high purchase amount? The total money customer spent
#
# If the customer bought in recent past, he gets higher points. If he bought many times, he gets higher score. And if he spent a lot of money, he gets more points.
#
# How to create segments?
# * Concatenate all scores into one, eg: 3-4-1 (R-F-M) and group customers according to those values. It gives 125 combinations which is difficult to depict and understand
# * Sum all scores into one, eg: 8 (3 + 4 + 1) and group customers according to this number. It creates 13 groups which is much easier to work with but it disregards relations between R & F & M
# * Segment customers based on set of rules applied to R-F-M scores. It creates 10 groups, such as "champions", "needing attention" or "at risk"

# %%
from pyhive import trino
from getpass import getpass
import pandas as pd
import awswrangler as wr
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from utils import *

# %%
df = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/card-use')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2313639 entries, 0 to 2313638
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   clientid   Int64
#  1   RECENCY    Int64
#  2   FREQUENCY  Int64
#  3   MONETARY   float64
# dtypes: Int64(3), float64(1)
# memory usage: 77.2 MB

# %%
df_dimension = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/dimension')
df_dimension.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19013668 entries, 0 to 19013667
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   clientid         Int64
#  1   presumedincome   float64
#  2   age              float64
#  3   ageneon          Int64
#  4   flaginviteduser  Int64
# dtypes: Int64(3), float64(2)
# memory usage: 779.7 MB

# %%
df = df.merge(df_dimension, on = 'clientid', how = 'left')
df
# Out:
#          clientid  RECENCY  FREQUENCY  MONETARY  presumedincome   age  \
# 0           12345        0         18   3231.26         1559.09  30.0
# 1        16789075        0          6    902.01         2110.00  49.0
# 2        22141562        0          3    337.90         1006.00  30.0
# 3        18388465        0          7    191.91         1211.98  45.0
# 4         8050971        0          6    537.82         1108.88  34.0
# ...           ...      ...        ...       ...             ...   ...
# 2313634  14389329       60          1     20.00         5106.04  27.0
# 2313635  10496686       60          1    109.98         2523.73  42.0
# 2313636  23513418       60          3    105.50         1654.00  44.0
# 2313637  23275339       60          1      2.00          910.00  23.0
# 2313638  23993444       60          1      4.00          837.00  19.0
#
#          ageneon  flaginviteduser
# 0             83                0
# 1             17                0
# 2              8                0
# 3             15                1
# 4             36                0
# ...          ...              ...
# 2313634       22                0
# 2313635       30                0
# 2313636        5                0
# 2313637        6                0
# 2313638        4                0
#
# [2313639 rows x 8 columns]

# %%
df_gh = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/gh')
df_gh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49401682 entries, 0 to 49401681
# Data columns (total 2 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   clientid  Int64
#  1   GH_VL     float64
# dtypes: Int64(1), float64(1)
# memory usage: 800.9 MB

# %%
df_gh_agg = df_gh.groupby('clientid')['GH_VL'].max().to_frame().reset_index()

# %%
df = df.merge(df_gh_agg, on = 'clientid', how = 'left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2313639 entries, 0 to 2313638
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   clientid         Int64
#  1   RECENCY          Int64
#  2   FREQUENCY        Int64
#  3   MONETARY         float64
#  4   presumedincome   float64
#  5   age              float64
#  6   ageneon          Int64
#  7   flaginviteduser  Int64
#  8   GH_VL            float64
# dtypes: Int64(5), float64(4)
# memory usage: 187.5 MB

# %%
df_viracredito = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/viracredito')
df_viracredito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197817283 entries, 0 to 197817282
# Data columns (total 2 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   clientid         Int64
#  1   tem_viracredito  Int64
# dtypes: Int64(2)
# memory usage: 3.3 GB

# %%
df_viracredito_agg = df_viracredito.groupby('clientid')['tem_viracredito'].sum().to_frame().reset_index()
df_viracredito_agg['viracredito_flag'] = 1
del df_viracredito_agg['tem_viracredito']
df_viracredito_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209612 entries, 0 to 1209611
# Data columns (total 2 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   clientid          1209612 non-null  int64
#  1   viracredito_flag  1209612 non-null  int64
# dtypes: int64(2)
# memory usage: 18.5 MB

# %%
df = df.merge(df_viracredito_agg, on = 'clientid', how = 'left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2313639 entries, 0 to 2313638
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   clientid          Int64
#  1   RECENCY           Int64
#  2   FREQUENCY         Int64
#  3   MONETARY          float64
#  4   presumedincome    float64
#  5   age               float64
#  6   ageneon           Int64
#  7   flaginviteduser   Int64
#  8   GH_VL             float64
#  9   viracredito_flag  float64
# dtypes: Int64(5), float64(5)
# memory usage: 205.2 MB

# %%
df_account_balance = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/account-balance')
df_account_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215701 entries, 0 to 11215700
# Data columns (total 2 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   clientid            Int64
#  1   ACCOUNT_BALANCE_VL  float64
# dtypes: Int64(1), float64(1)
# memory usage: 181.8 MB

# %%
df = df.merge(df_account_balance , on = 'clientid', how = 'left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2313639 entries, 0 to 2313638
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   clientid            Int64
#  1   RECENCY             Int64
#  2   FREQUENCY           Int64
#  3   MONETARY            float64
#  4   presumedincome      float64
#  5   age                 float64
#  6   ageneon             Int64
#  7   flaginviteduser     Int64
#  8   GH_VL               float64
#  9   viracredito_flag    float64
#  10  ACCOUNT_BALANCE_VL  float64
# dtypes: Int64(5), float64(6)
# memory usage: 222.9 MB

# %%
df_limite_credito = wr.s3.read_parquet('s3://neon-datascience-sandbox/segmentacao-cartoes/credito')
df_limite_credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4566768 entries, 0 to 4566767
# Data columns (total 5 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   clientid                 Int64
#  1   limitecreditototal       float64
#  2   debitoautomatico         boolean
#  3   limitecreditodisponivel  float64
#  4   diasatraso               float64
# dtypes: Int64(1), boolean(1), float64(3)
# memory usage: 152.4 MB

# %%
df = df.merge(df_limite_credito , on = 'clientid', how = 'left')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2313639 entries, 0 to 2313638
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   clientid                 Int64
#  1   RECENCY                  Int64
#  2   FREQUENCY                Int64
#  3   MONETARY                 float64
#  4   presumedincome           float64
#  5   age                      float64
#  6   ageneon                  Int64
#  7   flaginviteduser          Int64
#  8   GH_VL                    float64
#  9   viracredito_flag         float64
#  10  ACCOUNT_BALANCE_VL       float64
#  11  limitecreditototal       float64
#  12  debitoautomatico         boolean
#  13  limitecreditodisponivel  float64
#  14  diasatraso               float64
# dtypes: Int64(5), boolean(1), float64(9)
# memory usage: 280.2 MB

# %% [markdown]
# ## RFM Customer Segments
#
# * **Champions** - bought recently, buy often and spend the most
# * **Loyal Customers** - spend good money and often, responsive to promotions
# * **Potential Loyalist** - recent customers, but spent a good amount and bought more than once
# * **New Customers** - bought most recently, but not often
# * **Promising** - recent shoppers, but haven’t spent much
# * **Needing Attention** - above average recency, frequency and monetary values; may not have bought very recently though
# * **About To Sleep** - below average recency, frequency and monetary values; will lose them if not reactivated
# * **At Risk** - spent big money and purchased often but long time ago; need to bring them back
# * **Can't Loose Them** - made biggest purchases, and often but haven’t returned for a long time
# * **Hibernating** - last purchase was long back, low spenders and low number of orders

# %%
df["R"] = pd.qcut(df["RECENCY"],5,labels=[5,4,3,2,1])

df["F"] = pd.qcut(df["FREQUENCY"],5,labels=[1,2,3,4,5])

df["M"] = pd.qcut(df["MONETARY"],5,labels=[1,2,3,4,5])

# %%
df["RFM_Score"] = df["R"].astype(str) + df["F"].astype(str) + df["M"].astype(str)

# %%
df
# Out:
#          clientid  RECENCY  FREQUENCY  MONETARY  presumedincome   age  \
# 0           12345        0         18   3231.26         1559.09  30.0
# 1        16789075        0          6    902.01         2110.00  49.0
# 2        22141562        0          3    337.90         1006.00  30.0
# 3        18388465        0          7    191.91         1211.98  45.0
# 4         8050971        0          6    537.82         1108.88  34.0
# ...           ...      ...        ...       ...             ...   ...
# 2313634  14389329       60          1     20.00         5106.04  27.0
# 2313635  10496686       60          1    109.98         2523.73  42.0
# 2313636  23513418       60          3    105.50         1654.00  44.0
# 2313637  23275339       60          1      2.00          910.00  23.0
# 2313638  23993444       60          1      4.00          837.00  19.0
#
#          ageneon  flaginviteduser  GH_VL  viracredito_flag  \
# 0             83                0    7.0               NaN
# 1             17                0   10.0               NaN
# 2              8                0   10.0               1.0
# 3             15                1    9.0               NaN
# 4             36                0   10.0               NaN
# ...          ...              ...    ...               ...
# 2313634       22                0    5.0               NaN
# 2313635       30                0    6.0               1.0
# 2313636        5                0    2.0               1.0
# 2313637        6                0    5.0               1.0
# 2313638        4                0    3.0               1.0
#
#          ACCOUNT_BALANCE_VL  limitecreditototal  debitoautomatico  \
# 0                    601.15             4004.00             False
# 1                       NaN             4250.00             False
# 2                     34.62              693.00             False
# 3                   7115.17              600.00             False
# 4                      0.00             2700.00              True
# ...                     ...                 ...               ...
# 2313634                0.00              540.00              True
# 2313635                0.00              110.00              True
# 2313636             7499.32              130.09              True
# 2313637               12.46               50.00              True
# 2313638            11004.12               10.28             False
#
#          limitecreditodisponivel  diasatraso  R  F  M RFM_Score
# 0                        2203.48         3.0  5  4  5       545
# 1                        1692.63         1.0  5  2  4       524
# 2                          47.54         6.0  5  1  2       512
# 3                         278.08         6.0  5  2  2       522
# 4                        2030.83         0.0  5  2  3       523
# ...                          ...         ... .. .. ..       ...
# 2313634                     3.38        51.0  1  1  1       111
# 2313635                     1.03         6.0  1  1  1       111
# 2313636                     1.84         7.0  1  1  1       111
# 2313637                    50.00         3.0  1  1  1       111
# 2313638                     0.28         0.0  1  1  1       111
#
# [2313639 rows x 19 columns]

# %%
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Cant Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

# %%
df['Segment'] = df['R'].astype(str) + df['F'].astype(str)
df['Segment'] = df['Segment'].replace(seg_map, regex=True)
df.head()
# Out:
#    clientid  RECENCY  FREQUENCY  MONETARY  presumedincome   age  ageneon  \
# 0     12345        0         18   3231.26         1559.09  30.0       83
# 1  16789075        0          6    902.01         2110.00  49.0       17
# 2  22141562        0          3    337.90         1006.00  30.0        8
# 3  18388465        0          7    191.91         1211.98  45.0       15
# 4   8050971        0          6    537.82         1108.88  34.0       36
#
#    flaginviteduser  GH_VL  viracredito_flag  ACCOUNT_BALANCE_VL  \
# 0                0    7.0               NaN              601.15
# 1                0   10.0               NaN                 NaN
# 2                0   10.0               1.0               34.62
# 3                1    9.0               NaN             7115.17
# 4                0   10.0               NaN                0.00
#
#    limitecreditototal  debitoautomatico  limitecreditodisponivel  diasatraso  \
# 0              4004.0             False                  2203.48         3.0
# 1              4250.0             False                  1692.63         1.0
# 2               693.0             False                    47.54         6.0
# 3               600.0             False                   278.08         6.0
# 4              2700.0              True                  2030.83         0.0
#
#    R  F  M RFM_Score              Segment
# 0  5  4  5       545            Champions
# 1  5  2  4       524  Potential Loyalists
# 2  5  1  2       512        New Customers
# 3  5  2  2       522  Potential Loyalists
# 4  5  2  3       523  Potential Loyalists

# %%
segment_order = ['Hibernating',
                 'At Risk',
                 'Cant Loose',
                 'About to Sleep',
                 'Need Attention',
                 'Loyal Customers',
                 'Promising',
                 'New Customers',
                 'Potential Loyalists',
                 'Champions']

# %%
segment_means = df.groupby('Segment').agg({
    'RECENCY': 'mean',
    'FREQUENCY': 'mean',
    'MONETARY': 'mean',
    'presumedincome': 'mean', 
    'age': 'median',
    'ageneon': 'median', 
    'flaginviteduser': 'sum', 
    'GH_VL': 'mean', 
    'viracredito_flag': 'sum',
    'ACCOUNT_BALANCE_VL': 'mean', 
    'limitecreditototal': 'mean', 
    'debitoautomatico':'sum',
    'limitecreditodisponivel': 'mean', 
    'diasatraso': 'mean',
    'clientid': 'count'
}).reset_index().rename(columns={'clientid': 'count'})

segment_means['Segment'] = segment_means['Segment'].astype('string')

# %%
segment_means.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Segment                  10 non-null     string
#  1   RECENCY                  10 non-null     Float64
#  2   FREQUENCY                10 non-null     Float64
#  3   MONETARY                 10 non-null     float64
#  4   presumedincome           10 non-null     float64
#  5   age                      10 non-null     float64
#  6   ageneon                  10 non-null     Float64
#  7   flaginviteduser          10 non-null     Int64
#  8   GH_VL                    10 non-null     float64
#  9   viracredito_flag         10 non-null     float64
#  10  ACCOUNT_BALANCE_VL       10 non-null     float64
#  11  limitecreditototal       10 non-null     float64
#  12  debitoautomatico         10 non-null     Int64
#  13  limitecreditodisponivel  10 non-null     float64
#  14  diasatraso               10 non-null     float64
#  15  count                    10 non-null     int64
# dtypes: Float64(3), Int64(2), float64(9), int64(1), string(1)
# memory usage: 1.4 KB

# %%
segment_means
# Out:
#                Segment    RECENCY  FREQUENCY     MONETARY  presumedincome  \
# 0       About to Sleep   6.922284   4.047697   455.141923     1570.710772
# 1              At Risk  17.478035  13.338171   997.143017     1580.988953
# 2           Cant Loose  15.493978  37.121122  1947.280940     1669.777492
# 3            Champions   1.165869  35.127834  2045.490928     1793.444031
# 4          Hibernating  25.648644   3.083741   383.412400     1557.403988
# 5      Loyal Customers   5.258339  28.458997  1679.585176     1679.687614
# 6       Need Attention   6.834994  10.287133   857.939786     1586.410366
# 7        New Customers   1.361389   2.188991   279.443258     1599.954294
# 8  Potential Loyalists   1.993873   8.436336   752.974090     1605.477263
# 9            Promising   3.483758   2.118167   272.679688     1566.533101
#
#     age  ageneon  flaginviteduser  GH_VL  viracredito_flag  \
# 0  33.0     21.0            22980    8.0           44600.0
# 1  33.0     24.0            38954    8.0           56681.0
# 2  33.0     23.0             8599    8.0           13362.0
# 3  34.0     24.0            70949    8.0           73642.0
# 4  33.0     21.0            85219    8.0          200283.0
# 5  33.0     25.0            49846    8.0           56480.0
# 6  33.0     25.0            15841    8.0           19697.0
# 7  34.0     17.0             5881    8.0           12663.0
# 8  34.0     23.0            48147    8.0           60334.0
# 9  33.0     16.0             3851    8.0           10285.0
#
#    ACCOUNT_BALANCE_VL  limitecreditototal  debitoautomatico  \
# 0         6757.430735         1400.284906             95168
# 1         5340.571961         1519.267984            145808
# 2         5508.656860         1935.269791             31954
# 3         8894.189089         2749.857297            230142
# 4         5536.461134         1182.165995            357543
# 5         7576.278957         2205.509916            161711
# 6         7023.104996         1713.523914             56273
# 7         6653.672223         1377.748316             27082
# 8         7474.037331         1754.909503            181938
# 9         5847.544046         1266.977376             18716
#
#    limitecreditodisponivel  diasatraso   count
# 0               860.341027    9.515338  158397
# 1               863.121851    4.619911  260575
# 2              1172.999443    2.610581   58371
# 3              1632.657084    1.734179  439516
# 4               580.105155   17.004319  595490
# 5              1331.904440    2.088300  306976
# 6              1028.612965    3.890066  101796
# 7               874.629256   12.351076   43330
# 8              1089.798442    4.754175  319882
# 9               865.509478   10.409576   29306

# %%
segment_means['percent_mgm'] = (segment_means['flaginviteduser'] / segment_means['count']) * 100
segment_means['percent_debt_auto'] = (segment_means['debitoautomatico'] / segment_means['count']) * 100
segment_means['percent_viracredito'] = (segment_means['viracredito_flag'] / segment_means['count']) * 100
segment_means['percent_limite'] = (segment_means['limitecreditodisponivel'] / segment_means['limitecreditototal']) * 100

# %%
segment_means['Segment'] = pd.Categorical(segment_means['Segment'], categories=segment_order, ordered=True)
segment_means = segment_means.sort_values('Segment')

# %%
segment_means
# Out:
#                Segment    RECENCY  FREQUENCY     MONETARY  presumedincome  \
# 4          Hibernating  25.648644   3.083741   383.412400     1557.403988
# 1              At Risk  17.478035  13.338171   997.143017     1580.988953
# 2           Cant Loose  15.493978  37.121122  1947.280940     1669.777492
# 0       About to Sleep   6.922284   4.047697   455.141923     1570.710772
# 6       Need Attention   6.834994  10.287133   857.939786     1586.410366
# 5      Loyal Customers   5.258339  28.458997  1679.585176     1679.687614
# 9            Promising   3.483758   2.118167   272.679688     1566.533101
# 7        New Customers   1.361389   2.188991   279.443258     1599.954294
# 8  Potential Loyalists   1.993873   8.436336   752.974090     1605.477263
# 3            Champions   1.165869  35.127834  2045.490928     1793.444031
#
#     age  ageneon  flaginviteduser  GH_VL  viracredito_flag  \
# 4  33.0     21.0            85219    8.0          200283.0
# 1  33.0     24.0            38954    8.0           56681.0
# 2  33.0     23.0             8599    8.0           13362.0
# 0  33.0     21.0            22980    8.0           44600.0
# 6  33.0     25.0            15841    8.0           19697.0
# 5  33.0     25.0            49846    8.0           56480.0
# 9  33.0     16.0             3851    8.0           10285.0
# 7  34.0     17.0             5881    8.0           12663.0
# 8  34.0     23.0            48147    8.0           60334.0
# 3  34.0     24.0            70949    8.0           73642.0
#
#    ACCOUNT_BALANCE_VL  limitecreditototal  debitoautomatico  \
# 4         5536.461134         1182.165995            357543
# 1         5340.571961         1519.267984            145808
# 2         5508.656860         1935.269791             31954
# 0         6757.430735         1400.284906             95168
# 6         7023.104996         1713.523914             56273
# 5         7576.278957         2205.509916            161711
# 9         5847.544046         1266.977376             18716
# 7         6653.672223         1377.748316             27082
# 8         7474.037331         1754.909503            181938
# 3         8894.189089         2749.857297            230142
#
#    limitecreditodisponivel  diasatraso   count  percent_mgm  \
# 4               580.105155   17.004319  595490    14.310736
# 1               863.121851    4.619911  260575    14.949247
# 2              1172.999443    2.610581   58371     14.73163
# 0               860.341027    9.515338  158397    14.507851
# 6              1028.612965    3.890066  101796    15.561515
# 5              1331.904440    2.088300  306976    16.237751
# 9               865.509478   10.409576   29306    13.140654
# 7               874.629256   12.351076   43330    13.572583
# 8              1089.798442    4.754175  319882    15.051488
# 3              1632.657084    1.734179  439516     16.14253
#
#    percent_debt_auto  percent_viracredito
# 4          60.041814            33.633310
# 1          55.956251            21.752279
# 2          54.742937            22.891504
# 0          60.081946            28.157099
# 6          55.280168            19.349483
# 5          52.678711            18.398832
# 9          63.864055            35.095202
# 7          62.501731            29.224556
# 8          56.876598            18.861330
# 3          52.362599            16.755249

# %%
def plot_bar(
    df,
    segment,
    xlabel,
    ylabel,
    title,
    color
):
    plt.figure(figsize = (14, 6))
    bars = plt.bar(df['Segment'], df[segment], alpha = 0.7, color = color)

    for bar, value in zip(bars, df[segment]):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.15, str(round(value, 2)),
                 ha='center', va='bottom', fontsize=10)

    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xticks(rotation=45)  
    plt.tight_layout()

# %% [markdown]
# ## Plotting RECENCY, FREQUENCY and MONETARY

# %%
plot_bar(segment_means, 'count', 'Segments', 'Count', 'Total clients by segment', 'blue')

# %%
plot_bar(segment_means, 'RECENCY', 'Segments', 'Days', 'Mean RECENCY by segment', 'red')

# %%
plot_bar(segment_means, 'FREQUENCY', 'Segments', 'Qty', 'Mean FREQUENCY BY segment', 'violet')

# %%
plot_bar(segment_means, 'MONETARY', 'Segments', 'BRL', 'Mean MONETARY by segment', 'green')

# %% [markdown]
# ## Plotting of complementary data

# %%
segment_means.columns
# Out:
# Index(['Segment', 'RECENCY', 'FREQUENCY', 'MONETARY', 'presumedincome', 'age',
#        'ageneon', 'flaginviteduser', 'GH_VL', 'viracredito_flag',
#        'ACCOUNT_BALANCE_VL', 'limitecreditototal', 'debitoautomatico',
#        'limitecreditodisponivel', 'diasatraso', 'count', 'percent_mgm',
#        'percent_debt_auto', 'percent_viracredito'],
#       dtype='object')

# %%
plot_bar(segment_means, 'presumedincome', 'Segments', 'BRL', 'Presumed Income by segment', 'grey')

# %%
sns.set(rc={'figure.figsize':(3,6)}, style='whitegrid')
sns.boxplot(
             y ="presumedincome",
             data = segment_means)
# Out:
# <AxesSubplot:ylabel='presumedincome'>

# %%
plot_bar(segment_means, 'age', 'Segments', 'Age', 'Mean client age por segmento', 'grey')

# %%
sns.set(rc={'figure.figsize':(3,6)}, style='whitegrid')
sns.boxplot(
             y ="age",
             data = segment_means)
# Out:
# <AxesSubplot:ylabel='age'>

# %%
plot_bar(segment_means, 'ageneon', 'Segmentos', 'BRL', 'Age Neon por segmento')

# %%
plot_bar(segment_means, 'GH_VL', 'Segmentos', 'BRL', 'GH_VL por segmento', 'grey')

# %%
sns.set(rc={'figure.figsize':(3,6)}, style='whitegrid')
sns.boxplot(
             y ="GH_VL",
             data = segment_means)
# Out:
# <AxesSubplot:ylabel='GH_VL'>

# %%
segment_means.columns
# Out:
# Index(['Segment', 'RECENCY', 'FREQUENCY', 'MONETARY', 'presumedincome', 'age',
#        'ageneon', 'flaginviteduser', 'GH_VL', 'viracredito_flag',
#        'ACCOUNT_BALANCE_VL', 'limitecreditototal', 'debitoautomatico',
#        'limitecreditodisponivel', 'diasatraso', 'count', 'percent_mgm',
#        'percent_debt_auto', 'percent_viracredito', 'percent_limite'],
#       dtype='object')

# %%
plot_bar(segment_means, 'ACCOUNT_BALANCE_VL', 'Segmentos', 'BRL', 'Account Balance por segmento')

# %%
plot_bar(segment_means, 'diasatraso', 'Segmentos', 'BRL', 'Dias Atraso por segmento')

# %%
plot_bar(segment_means, 'limitecreditototal', 'Segmentos', 'BRL', 'Limite por segmento')

# %%
plot_bar(segment_means, 'limitecreditodisponivel', 'Segmentos', 'BRL', 'Limite disp por segmento')

# %%
# percent_limite
plot_bar(segment_means, 'percent_limite', 'Segmentos', 'BRL', 'Limite disp por segmento')

# %%
plot_bar(segment_means, 'percent_mgm', 'Segmentos', 'BRL', 'Limite disp por segmento')

# %%
plot_bar(segment_means, 'percent_debt_auto', 'Segmentos', 'BRL', 'Percentual debito autom por segmento')

# %%
#percent_viracredito
plot_bar(segment_means, 'percent_viracredito', 'Segmentos', 'BRL', 'Percentual usado do limite por segmento')

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

data_rfm = df.iloc[df.values==np.inf][['clientid','RECENCY','FREQUENCY','MONETARY']].value

data_log = np.log(data_rfm)
scaler = StandardScaler()
scaler.fit(data_log)
data_normalized = scaler.transform(data_log)
data_normalized = pd.DataFrame(data=data_normalized, index=data_rfm.index, columns=data_rfm.columns)
# Out:
# /tmp/ipykernel_220/2770969978.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   data_rfm = df.iloc[df.values==np.inf][['clientid','RECENCY','FREQUENCY','MONETARY']].value
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[251], line 4
#       1 import numpy as np
#       2 from sklearn.preprocessing import StandardScaler
# ----> 4 data_rfm = df.iloc[df.values==np.inf][['clientid','RECENCY','FREQUENCY','MONETARY']].value
#       6 data_log = np.log(data_rfm)
#       7 scaler = StandardScaler()
#
# File /opt/conda/envs/datalake/lib/python3.8/site-packages/pandas/core/indexing.py:895, in _LocationIndexer.__getitem__(self, key)
#     892 axis = self.axis or 0
#     894 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/conda/envs/datalake/lib/python3.8/site-packages/pandas/core/indexing.py:1498, in _iLocIndexer._getitem_axis(self, key, axis)
#    1496 key = item_from_zerodim(key)
#    1497 if not is_integer(key):
# -> 1498     raise TypeError("Cannot index by location index with a non-integer key")
#    1500 # validate the location
#    1501 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key
